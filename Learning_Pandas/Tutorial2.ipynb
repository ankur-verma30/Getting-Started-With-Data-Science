# %%
import pandas as pd
df=pd.read_csv('/content/weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
#to print the initial some data of your data frame then it will be
df.head()
#can customize the head also by passing the parameter of number inside the head
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
#similarly we can print the tail of the data frame
df.tail()
#prints last 5 rows similarly we can also customize the tail by passing paramter in the function
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# **Indexing and Slicing on Data Frames**

# %%
df[0:2]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
#To print the columns of the dataframe is
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
#Method 1 to access a column using dot opeator on objects
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
# Method 2 both are same as Using key value pair notation like dictionary
df['event'].unique() # for getting the unique values
# Out:
# array(['Rain', 'Sunny', 'Snow'], dtype=object)

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
#to print only certain columns
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %% [markdown]
# **Operations on Data Frames**

# %%
df['temperature'].max()
# Out:
# 35

# %% [markdown]
# **bold text**

# %%
df['windspeed'].max()
# Out:
# 7

# %%
df['windspeed'].mean()
# Out:
# np.float64(4.666666666666667)

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
#conditional rendering of the dataframe
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[df.temperature==df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
# If you column name contains spaced dot notation will not work
df[df.temperature==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
#to select what was the day when this event has happened
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#setting the index as the day parameter
df.set_index('day',inplace=True)

# %%
df.loc['1/3/2017']
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#    level_0  index       day  temperature  windspeed  event
# 0        0      0  1/1/2017           32          6   Rain
# 1        1      1  1/2/2017           35          7  Sunny
# 2        2      2  1/3/2017           28          2   Snow
# 3        3      3  1/4/2017           24          7   Snow
# 4        4      4  1/5/2017           32          4   Rain
# 5        5      5  1/6/2017           31          2  Sunny

# %%
del df['level_0']

# %%
df
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4   Rain
# 5      5  1/6/2017           31          2  Sunny

# %% [markdown]
# #If the index is common for more than one columns it will print all the columns that satisfies the index

# %%
new_df=df
new_df
# Out:
#        index       day  temperature  windspeed
# event
# Rain       0  1/1/2017           32          6
# Sunny      1  1/2/2017           35          7
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7
# Rain       4  1/5/2017           32          4
# Sunny      5  1/6/2017           31          2

# %%
new_df.loc['Snow']
# Out:
#        index       day  temperature  windspeed
# event
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7
